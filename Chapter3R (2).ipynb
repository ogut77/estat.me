# %%
# read the data file
url='https://raw.githubusercontent.com/ogut77/DataScience/refs/heads/main/PurchaseByCredit40.csv'
card <- read.csv(url, header=TRUE, as.is=FALSE)

# %%
card
# Out:
#    id Gender Age Income Credit Purchase
# 1   1 male   20s LT2000 Fair   Yes
# 2   2 female 30s GE2000 Good   No
# 3   3 female 20s GE2000 Fair   No
# 4   4 female 20s GE2000 Fair   Yes
# 5   5 female 20s LT2000 Bad    No
# 6   6 female 30s GE2000 Fair   No
# 7   7 female 30s GE2000 Good   Yes
# 8   8 male   20s LT2000 Fair   No
# 9   9 female 20s GE2000 Good   No
# 10 10 male   30s GE2000 Fair   Yes
# 11 11 female 30s GE2000 Good   Yes
# 12 12 female 20s LT2000 Fair   No
# 13 13 male   30s GE2000 Fair   No
# 14 14 male   30s LT2000 Fair   Yes
# 15 15 female 30s GE2000 Good   Yes
# 16 16 female 30s GE2000 Fair   No
# 17 17 female 20s GE2000 Bad    No
# 18 18 male   20s GE2000 Bad    No
# 19 19 male   30s GE2000 Good   Yes
# 20 20 male   20s LT2000 Fair   No
# 21 21 male   20s LT2000 Fair   Yes
# 22 22 female 30s GE2000 Good   No
# 23 23 female 20s GE2000 Fair   No
# 24 24 female 20s GE2000 Fair   Yes
# 25 25 female 20s LT2000 Bad    No
# 26 26 female 30s GE2000 Fair   No
# ...

# %%
attach(card)

# %%
# Bar graph
plot(Purchase, main="Bar Graph", ylab="frequency", ylim=c(0,30))
# Out:
# Plot with title “Bar Graph”

# %%
# Pie chart
freq <- table(Purchase)
freq
# Out:
# Purchase
#  No Yes
#  24  16

# %%
pie(freq, main="Pie Chart")
# Out:
# Plot with title “Pie Chart”

# %%
# Load the iris dataset (it's built-in)
data(iris)

# Display the first few rows
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
attach(iris)

# %%
# Continuous Data Histogram, Scatter plot
# Histogram
hist(Sepal.Length, col="lightgray", ylim=c(0,30), main="Histogram")
# Out:
# Plot with title “Histogram”

# %%
# Scatter plot
plot(Sepal.Length, Sepal.Width, main="Scatter Plot")
# Out:
# Plot with title “Scatter Plot”

# %%
# Continuous Data Paralle Coordinate Plot
# Divide iris data between the numerical and the categorical variable.
 quantData <- iris[, 1:4]
 quantData
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1   5.1          3.5         1.4          0.2
# 2   4.9          3.0         1.4          0.2
# 3   4.7          3.2         1.3          0.2
# 4   4.6          3.1         1.5          0.2
# 5   5.0          3.6         1.4          0.2
# 6   5.4          3.9         1.7          0.4
# 7   4.6          3.4         1.4          0.3
# 8   5.0          3.4         1.5          0.2
# 9   4.4          2.9         1.4          0.2
# 10  4.9          3.1         1.5          0.1
# 11  5.4          3.7         1.5          0.2
# 12  4.8          3.4         1.6          0.2
# 13  4.8          3.0         1.4          0.1
# 14  4.3          3.0         1.1          0.1
# 15  5.8          4.0         1.2          0.2
# 16  5.7          4.4         1.5          0.4
# 17  5.4          3.9         1.3          0.4
# 18  5.1          3.5         1.4          0.3
# 19  5.7          3.8         1.7          0.3
# ...

# %%
groupData <- iris[, 5]

# %%
library(MASS)

# %%
parcoord(quantData)
# Out:
# plot without title

# %%
# Categorical variable as colors
cols <- as.numeric(groupData)

# %%
parcoord(quantData, col = cols)
# Out:
# plot without title
